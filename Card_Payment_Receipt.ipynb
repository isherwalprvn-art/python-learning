# %% [markdown]
# # We have to print card payment message we have after making any transaction like we have 16 digit card but in message it should only last four digits only
# # Card number should be input from user.
#
#
# #  Transaction Alert
# # Amount Rs. 1000 has been
# # debited from your card.
# # **** **** **** 5678

# %% [markdown]
# print('\033[91m' + 'Red Text'    + '\033[0m')   # ❌ Errors
# print('\033[92m' + 'Green Text'  + '\033[0m')   # ✅ Success
# print('\033[93m' + 'Yellow Text' + '\033[0m')   # ⚠️ Warning
# print('\033[94m' + 'Blue Text'   + '\033[0m')   # ℹ️ Info
# print('\033[95m' + 'Purple Text' + '\033[0m')   # 🔔 Special

# %%
#Learning code 

Card_Number = input('Enter your 16 digits Card Number')
#Name_on_Card = input('Enter your Name on card')
#Expiry_Date = input('Enter your Card expiry date in MM/Year format')
#CVV = input('Enter your CVV')


RED   = '\033[91m'
GREEN = '\033[92m'
RESET = '\033[0m'

if len(Card_Number) != 16:
    print(f'{RED}Enter correct card number{RESET}')

elif len(Card_Number) == 16:
    formatted = (Card_Number[0:4] + ' ' +   # ✅ String slicing
                 Card_Number[4:8] + ' ' +
                 Card_Number[8:12] + ' ' +
                 Card_Number[12:16])
    print(f'{GREEN}{formatted}{RESET}')
# Out:
# 1234 5678 9098 7654

# %%
Red   = '\033[91m'
Green = '\033[92m'
Reset = '\033[0m'

Card_Number = input('Enter your 16 digit Card Number: ')
Amount      = input('Enter transaction amount: ')

if len(Card_Number) != 16:
    print(f'{Red}Please enter correct card number{Reset}')

elif len(Card_Number) == 16:
    card_secure = '*' * 12
    Card_show   = Card_Number[12:]
    formatted   = (card_secure[0:4] + ' ' +
                   card_secure[4:8] + ' ' +
                   card_secure[8:12])

    print(f'''
{Green}============================
     Transaction Alert 🔔
============================
Amount Rs.{Amount} has been
debited from your Card.
{formatted} {Card_show}
============================{Reset}
    ''')
# Out:
# ...
#      Transaction Alert 🔔
# ...
# Amount Rs.3000 has been
# debited from your Card.
# **** **** **** 8765
# ...
