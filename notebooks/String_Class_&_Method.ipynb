# %% [markdown]
# # String Class and its Methods
#
#
# # find (sub,start,end)
#
# # Find method will search for a given substring and gives it index and it will search in the entire (you can also indicate starting and end point to search a substring)
# # It take three peramete substring , start and end.
# # ** if any substring is not found then it will return the index minus one(-1)
#
# # rfind(sub,start,end)
#
# # it is working same as find just it will start to find the substsring from the end.
# # ** if any sunstring is not found then it will give you an error (Value error : substring not found). That is the only difference between find and index otherwise both work same.
#
# # index(sub,start,end)
#
# # count(sub,start,end)
# # find the occurences of the substring.
#
# # from this you can get all the method on string available in python
#
# # Alignment & Padding
#
# # ljust(width, fillchar) #width uis mandatory and fillchar is optional. It will align string to left.
# # width is for how much width you want of a string.
#
# # rjust(width,fillcahr)
# # same as ljust it just align string into right side.
#
# # center(width,fillchar)
# # same as ljust and rjust it just align string into the center.
#
# # zfill(width)
# # it will fill the empty spacew with zero but only on left side (if any string is the center and both side have space then it will move the stroing into right side and fill the space with zero in left side.)
#
# # Strip methods
#
# # lstrip(chars) #chars is optional if you do give any char here then it will space from left side.
#
# # rstrip(chars) # same work like lstrip just remove the char or space from the right side.
#
# # strip(chars) # remove the space or char from both side.
#
# # join & split
#
# # replace(old,new,count)
#
# # join(iterable)
#
# # spilt(sep,maxspilt)
# # if you do not give any sep char then bydefault it will split from the space char.
#
# # rspilt(sep,maxsplit)
# # same work like split it just start from the right hand side.
#
# # splitlines
# # if a string having a multiple lines, means multiline text is there in the string so you can separate all the line one by one. it will split them line wise.
#
# # Prefix and suffix of a
#
# # Startswith(prefix,start,end)
# # it will check whether this string is starting with a given substring or prefix.
#
# # endswith(prefix,start,end)
# # it will check whether this string is ending with a given substring or prefix.
#
# # removeprefix(prefix)
# # if the prefix found it will remove it.
#
# # removesuffix(suffix)
# # if the suffix found it will remove it.
#
# # partition(sep)
#
#
# # capitalize()
# # it will convert first letter of string into capital letter.
#
# # upper()
# # it will convert complete string into in UPPER case.
#
# # lower()
# # it will convert complete string into in lower case.
#
# # title()
# # it will convert every word's first letter as capital.
#
# # swapcase()
# # it will swap the letter like it will convert upper letter into lower and lower into upper letter.
#
#
#
#
#
#
#
#
# #  Method 1 to get the list of methods
#
# # dir(str)
#
# # Method 2 to get the list of methods
# # s = 'Hello'
#
# # dir(s)

# %% [markdown]
# Python String Practice Questions
#
# 1️⃣ Basic Level
# Question 1
# Write a program to count the number of vowels in a string.
#
# Example
#
# Input
# Hello World
#
# Output
# 3
#
# Question 2
# Write a program to reverse a string.
#
# Example
#
# Input
# Python
#
# Output
# nohtyP
#
# Question 3
# Check whether a string is a palindrome or not.
#
# Example
#
# madam → Palindrome
# hello → Not Palindrome
#
# Question 4
# Count the number of words in a string.
#
# Example
# Input: I love Python programming
#
# Output: 4
# Hint: Use split().
#
# Question 5
# Convert the first letter of every word into uppercase.
#
# Example
#
# Input: hello world python
# Output: Hello World Python
# Hint: Use title().
#
#
# 2️⃣ Intermediate Level
#
# Question 6
# Find the frequency of each character in a string.
#
# Example
# Input: banana
# Output:
# b = 1
# a = 3
# n = 2
#
# Question 7
# Remove all spaces from a string.
#
# Example
# Input: Hello World Python
#
# Output: HelloWorldPython
#
# Question 8
#
# Find the largest word in a sentence.
#
# Example
#
# Input: I love programming in Python
# Output: programming
#
# Question 9
# Replace all vowels with *.
#
# Example
#
# Input: Hello
# Output: H*ll*
#
# Question 10
# Count how many times a substring appears in a string.
#
# Example
#
# Input: banana
# Substring: an
# Output: 2
# Hint: count().
#
# 3️⃣ Interview Level
#
# Question 11
# Check whether two strings are anagrams.
#
# Example
# listen
# silent
#
# Output
# Anagram
#
# Question 12
# Find the first non-repeating character.
#
# Example
#
# Input: swiss
# Output: w
#
# Question 13
# Remove duplicate characters from a string.
#
#
# Example
# Input: programming
# Output: progamin
#
#
# Question 14
# Find the second most frequent character in a string.
#
# Example
# Input: banana
# Output: n
#
# Question 15
#
# Compress a string.
#
# Example
#
# Input: aaabbcc
# Output: a3b2c2
