# %%
file = open('/Users/parveenisherwal/Library/Mobile Documents/com~apple~CloudDocs/AI_Study/Learning/data/data.txt','r')

data = file.read()

print(data)

file.close()
# Out:
# Just Read the File
# Name Parveen

# %%
file = open("/Users/parveenisherwal/Library/Mobile Documents/com~apple~CloudDocs/AI_Study/Learning/data/create_from_py","w")

data = ''' Name: Parveen 
Task: This file is created from python for learning file handling'''

file.write(data)

file.close()

# %%
file = open("/Users/parveenisherwal/Library/Mobile Documents/com~apple~CloudDocs/AI_Study/Learning/data/create_from_py","r")

data_1 = file.read()

print(data_1)

file.close()
# Out:
#  Name: Parveen
# Task: This file is created from python for learning file handling
