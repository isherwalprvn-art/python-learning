# %%
pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-9.4.0-cp39-cp39-macosx_14_0_arm64.whl.metadata (7.3 kB)
# Downloading mysql_connector_python-9.4.0-cp39-cp39-macosx_14_0_arm64.whl (17.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.5/17.5 MB 10.3 MB/s  0:00:01 eta 0:00:01
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.4.0
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Mysql@797920"
)

print("Connected to MySQL!")

cursor = conn.cursor(buffered=True)
# Out:
# Connected to MySQL!

# %%
cursor.execute("CREATE DATABASE univ")

print("Database created!")
# Out:
# Database created!

# %%
cursor.execute("USE univ")


cursor.execute("""
CREATE TABLE dept (
    dept_no INT PRIMARY KEY,
    dname VARCHAR(50)
)
""")

conn.commit()
print("Table created!")

cursor.close()
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 cursor.execute("USE univ")
#       4 cursor.execute("""
#       5 CREATE TABLE dept (
#       6     dept_no INT PRIMARY KEY,
#       7     dname VARCHAR(50)
#       8 )
#       9 """)
#      11 conn.commit()
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/AI_Study/Learning/.venv/lib/python3.9/site-packages/mysql/connector/cursor_cext.py:315, in CMySQLCursor.execute(self, operation, params, map_results)
#     312 except (ProgrammingError, ReferenceError) as err:
#     313     raise ProgrammingError("Cursor is not connected", 2055) from err
# --> 315 self._connection.handle_unread_result()
#     316 self.reset()
#     318 stmt = b""
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/AI_Study/Learning/.venv/lib/python3.9/site-packages/mysql/connector/connection_cext.py:1121, in CMySQLConnection.handle_unread_result(self, prepared)
#    1119     self.consume_results()
#    1120 elif unread_result:
# -> 1121     raise InternalError("Unread result found")
#
# InternalError: Unread result found

# %%
#cursor.execute("""insert into dept value(1,'prvn')""")

#cursor.execute("""insert into dept value(2,'Sneha')""")

#conn.commit()

cursor.close()
# Out:
# False

# %%
cursor.execute("USE univ")


cursor.execute("SELECT * FROM dept")

for row in cursor.fetchall():
    print(row)


cursor.close()
# Out:
# (1, 'prvn')
# (2, 'Sneha')
# True

# %%
conn.close()
