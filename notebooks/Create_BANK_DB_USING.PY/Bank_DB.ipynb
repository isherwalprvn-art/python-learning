# %%
pip install mysql-connector-python
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Mysql@797920"
)

print("Connected to MySQL!")

cursor = conn.cursor(buffered=True)
# Out:
# Connected to MySQL!

# %%
cursor.execute("Create DATABASE Bank_Details")

print("Done")
# Out:
# Done

# %%
cursor.execute("Use Bank_Details")

# %%
cursor.execute("""
Create Table customer(Cust_id INT primary key, name Varchar(255), city Varchar(50) , email Varchar(50) Unique)
""")

conn.commit

print("table created")

cursor.close()
# Out:
# table created
# True

# %%
cursor = conn.cursor(buffered=True)

cursor.execute("""
Insert into customer value(1,'Sneha','Pune','Snehagujar269@gmail.com'),(2,'Prvn','Dhani Gopal','Sisherwalprvn@gmail.com')
""")

conn.commit

print('Done')

cursor.close()
# Out:
# Done
# True

# %%
cursor = conn.cursor(buffered=True)

cursor.execute("Select * from customer")

for row in cursor.fetchall():
    print(row)

cursor.close
# Out:
# (1, 'Sneha', 'Pune', 'Snehagujar269@gmail.com')
# (2, 'Prvn', 'Dhani Gopal', 'Sisherwalprvn@gmail.com')
# <bound method CMySQLCursor.close of <mysql.connector.cursor_cext.CMySQLCursorBuffered object at 0x111c28580>>

# %%
cursor = conn.cursor(buffered=True)

cursor.execute("""
Create table Accounts()
""")
